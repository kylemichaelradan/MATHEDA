# %% [markdown]
# # Lists and Tuples <hr style="border:2.5px solid #5c3ef2ff\"></hr>

# %% [markdown]
# <b>Kyle Michael C. Radan</b>
# <br>Computer Engineer

# %% [markdown]
# # Creating A List

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers[0]
# Out:
# 1

# %%
type(numbers)
# Out:
# list

# %%
fruits = ['apple','banana','grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
'apple' in fruits
# Out:
# True

# %%
mixed_list = [10, 'hello', 2.5, True]
mixed_list
# Out:
# [10, 'hello', 2.5, True]

# %% [markdown]
# # Modifying

# %%
fruits = ['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
fruits[0] = 'orange' 
fruits
# Out:
# ['orange', 'banana', 'grape']

# %%
'orange' in fruits
# Out:
# True

# %% [markdown]
# # Adding Elements

# %%
fruits = ['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
fruits.append('orange')
fruits
# Out:
# ['apple', 'banana', 'grape', 'orange']

# %%
fruits.insert(1, 'blueberry')
fruits
# Out:
# ['apple', 'blueberry', 'banana', 'grape', 'orange']

# %% [markdown]
# # Removing Elements

# %%
fruits = ['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
'banana' in fruits
# Out:
# True

# %%
fruits.remove('banana')

# %%
'banana' in fruits
# Out:
# False

# %%
fruits
# Out:
# ['apple', 'grape']

# %%
fruits.pop(0)
# Out:
# 'apple'

# %% [markdown]
# # Sort() and Sorted()

# %%
numbers = [3,1,2,5,4]
numbers
# Out:
# [3, 1, 2, 5, 4]

# %%
sorted(numbers, reverse=True)
# Out:
# [5, 4, 3, 2, 1]

# %%
sorted(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers
# Out:
# [3, 1, 2, 5, 4]

# %%
numbers.sort(reverse=True)
numbers
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# # Slicing

# %%
chars = ['a', 'b', 'c', 'x', 'y']
chars
# Out:
# ['a', 'b', 'c', 'x', 'y']

# %%
len(chars)
# Out:
# 5

# %%
chars[1:4]
# Out:
# ['b', 'c', 'x']

# %%
sub = chars[1:4]
sub
# Out:
# ['b', 'c', 'x']

# %%
chars[0:5:2]
# Out:
# ['a', 'c', 'y']

# %% [markdown]
# # Tuple

# %%
my_tuple = (1,2,3,4,5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[2]
# Out:
# 3

# %%
my_tuple[1:3]
# Out:
# (2, 3)

# %%
my_tuple = (2,2,3,4,5)
my_tuple
# Out:
# (2, 2, 3, 4, 5)

# %%
mixed_tuple = (10, 'hello world', 2.5, True)
mixed_tuple
# Out:
# (10, 'hello world', 2.5, True)
